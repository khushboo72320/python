# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\abC\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\abC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\abC\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\abC\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\abC\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sys
print(f"pandas version:{pd.__version__}")
print(f"numpy version:{np.__version__}")
print("hello world")
# Out:
# pandas version:3.0.3
# numpy version:2.4.6
# hello world

# %%
import pandas as pd
Series1=pd.Series([10,20,30,40],name="ages")
print(Series1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: ages, dtype: int64

# %%
manual_df=pd.DataFrame({
    "Name":["article","bob","charie"],
    "Age":[23,45,67],
    "Income":[50000,56000,34300]
})
print("\nmanually created dataframe:\n",manual_df)
print("\ndataframe shape(rows,coloumns):",manual_df.shape)
# Out:
# manually created dataframe:
#        Name  Age  Income
# 0  article   23   50000
# 1      bob   45   56000
# 2   charie   67   34300
#
# dataframe shape(rows,coloumns): (3, 3)
