# %%
import pandas as pd
df=pd.read_csv('credit_card_fraud_10k.csv')
df
# Out:
#       transaction_id  amount  transaction_hour merchant_category  \
# 0                  1   84.47                22       Electronics
# 1                  2  541.82                 3            Travel
# 2                  3  237.01                17           Grocery
# 3                  4  164.33                 4           Grocery
# 4                  5   30.53                15              Food
# ...              ...     ...               ...               ...
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                       0                  0                  66
# ...

# %%
df.head(10)
# Out:
#    transaction_id  amount  transaction_hour merchant_category  \
# 0               1   84.47                22       Electronics
# 1               2  541.82                 3            Travel
# 2               3  237.01                17           Grocery
# 3               4  164.33                 4           Grocery
# 4               5   30.53                15              Food
# 5               6   30.53                13          Clothing
# 6               7   10.77                18            Travel
# 7               8  362.02                13       Electronics
# 8               9  165.43                 8           Grocery
# 9              10  221.63                 5           Grocery
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                  66
# 1                    1                  0                  87
# 2                    0                  0                  49
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       transaction_id  amount  transaction_hour merchant_category  \
# 0                  1   84.47                22       Electronics
# 1                  2  541.82                 3            Travel
# 2                  3  237.01                17           Grocery
# 3                  4  164.33                 4           Grocery
# 4                  5   30.53                15              Food
# ...              ...     ...               ...               ...
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                       0                  0                  66
# ...

# %%
df.shape[0]
# Out:
# 10000

# %%
df.dtypes
# Out:
# transaction_id           int64
# amount                 float64
# transaction_hour         int64
# merchant_category          str
# foreign_transaction      int64
# location_mismatch        int64
# device_trust_score       int64
# velocity_last_24h        int64
# cardholder_age           int64
# is_fraud                 int64
# dtype: object

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of       transaction_id  amount  transaction_hour merchant_category  \
# 0                  1   84.47                22       Electronics
# 1                  2  541.82                 3            Travel
# 2                  3  237.01                17           Grocery
# 3                  4  164.33                 4           Grocery
# 4                  5   30.53                15              Food
# ...              ...     ...               ...               ...
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                       0                  0                  66
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(7,4))
sns.scatterplot(data=df,x='transaction_id',y='amount',color='gold',marker='*',edgecolor='darkgoldenrod')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\MinGW\bin\ipykernel_10944\2111792951.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.isnull()
# Out:
#       transaction_id  amount  transaction_hour  merchant_category  \
# 0              False   False             False              False
# 1              False   False             False              False
# 2              False   False             False              False
# 3              False   False             False              False
# 4              False   False             False              False
# ...              ...     ...               ...                ...
# 9995           False   False             False              False
# 9996           False   False             False              False
# 9997           False   False             False              False
# 9998           False   False             False              False
# 9999           False   False             False              False
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                   False              False               False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['amount'].mean()
# Out:
# np.float64(175.94984899999997)

# %%
sns.histplot(data=df,x='transaction_hour',color='red')
plt.xlabel('time',fontsize=12)
plt.ylabel('number of frauds',fontsize=12)
# Out:
# Text(0, 0.5, 'number of frauds')

# %%
sns.countplot(data=df,x='is_fraud',color='red')
# Out:
# <Axes: xlabel='is_fraud', ylabel='count'>

# %%
sns.boxplot(data=df,x='is_fraud', y='amount')
# Out:
# <Axes: xlabel='is_fraud', ylabel='amount'>

# %%
sns.countplot(data=df,x='transaction_hour', hue='is_fraud')
# Out:
# <Axes: xlabel='transaction_hour', ylabel='count'>

# %%
sns.countplot(data=df,x='merchant_category', hue='is_fraud')
# Out:
# <Axes: xlabel='merchant_category', ylabel='count'>

# %%
sns.countplot(data=df,x='foreign_transaction', hue='is_fraud',color='green')
# Out:
# C:\MinGW\bin\ipykernel_10944\2455555096.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:green'` for the same effect.
#
#   sns.countplot(data=df,x='foreign_transaction', hue='is_fraud',color='green')
# <Axes: xlabel='foreign_transaction', ylabel='count'>

# %%
sns.countplot(data=df,x='location_mismatch', hue='is_fraud')
# Out:
# <Axes: xlabel='location_mismatch', ylabel='count'>

# %%
sns.boxplot(data=df,x='is_fraud', y='device_trust_score')
# Out:
# <Axes: xlabel='is_fraud', ylabel='device_trust_score'>

# %%
sns.boxplot(data=df,x='is_fraud', y='velocity_last_24h')
# Out:
# <Axes: xlabel='is_fraud', ylabel='velocity_last_24h'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df.amount()
#
# TypeError: 'Series' object is not callable
