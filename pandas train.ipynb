# %%
import pandas as pd
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.iloc[1:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
import pandas as pd
df["Fare"]
print(type(df["Fare"]))
# Out:
# <class 'pandas.Series'>

# %%
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
cols=["Name","Age","Sex"]
df.loc[0:5,cols]
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                   Moran, Mr. James   NaN    male

# %%
df.iloc[10:15,0:5]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex
# 10  female
# 11  female
# 12    male
# 13    male
# 14  female

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
Survived=df[df["Survived"]==1]
print("Survived")
print(len (Survived))
# Out:
# Survived
# 342

# %%
df["Survived"]==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
df["Survived"]==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
mean=df["Fare"].mean()
print(mean)
# Out:
# 32.204207968574636

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
total=df.groupby("Pclass")["Survived"].sum()
print("total")
print(total.sum())
# Out:
# total
# 342

# %%
data=df[df["Pclass"]==1]
print(data)
print(len(data))
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
gender=df[(df["Sex"]=="female")&(df["Survived"]==1)]
len(gender)
# Out:
# 233

# %%
data=df[df["Fare"]>100]
len (data)
# Out:
# 53

# %%
df.groupby("Sex")["Survived"].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
age_median=df["Age"].median()
print(age_median)
# Out:
# 28.0

# %%
age_median=df["Age"].median()
print(age_median)
df["Age"]=df["Age"].fillna(age_median)
df.isnull().sum()
# Out:
# 28.0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.929936
# male      30.140676
# Name: Age, dtype: float64

# %%
data=["Age","Fare"]
df.groupby("Survived")[data].mean()
# Out:
#                 Age       Fare
# Survived
# 0         30.028233  22.117887
# 1         28.291433  48.395408

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.groupby("Parch")["Survived"].sum()
# Out:
# Parch
# 0    233
# 1     65
# 2     40
# 3      3
# 4      0
# 5      1
# 6      0
# Name: Survived, dtype: int64

# %%
df.groupby("Parch")["Fare"].mean()
# Out:
# Parch
# 0    25.586774
# 1    46.778180
# 2    64.337604
# 3    25.951660
# 4    84.968750
# 5    32.550000
# 6    46.900000
# Name: Fare, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("train.csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("train.csv")
plt.figure(figsize=(7,4))
sns.histplot(data=df,x='Age',kde='True',color='purple')
plt.title("passanger distribution",fontsize=12)
plt.xlabel("passengers")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\MinGW\bin\ipykernel_2260\3255296509.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("train.csv")
plt.figure(figsize=(7,4))
sns.countplot(data=df,x="Survived",palette="Set2")
plt.title("passenger survived",fontsize=12)
plt.show()
# Out:
# C:\MinGW\bin\ipykernel_2260\789334616.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Survived",palette="Set2")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("train.csv")
plt.figure(figsize=(7,4))
sns.countplot(data=df,x="Sex",)
plt.title("gender",fontsize=12)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("train.csv")
plt.figure(figsize=(7,4))
sns.boxplot(data=df,x="Fare",color="red")
plt.title("fare",fontsize=12)
plt.xlabel("Fare",fontsize=12)
plt.grid(True)
plt.legend()
df.Fare.median()
median_age=df['Age'].median()
df['Age']=df['Age'].fillna(median_age)
plt.show()
# Out:
# C:\MinGW\bin\ipykernel_2260\4148961870.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
median_age=df['Age'].median()
df['Age']=df['Age'].fillna(median_age)
plt.figure(figsize=(7,4))
sns.scatterplot(df,x='Age',y='Fare',color='red',hue='Survived')
plt.title("Survived",fontsize=12)
plt.xlabel("Age",fontsize=12)
plt.grid(True)
plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('train.csv')
df
columns=['Survived','Pclass','Age','Fare']
corr=df[columns].corr()
sns.heatmap(data=corr,annot=True,cmap="coolwarm",vmin= -1,vmax= 1)
plt.title('correlation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 8
#       4 df=pd.read_csv('train.csv')
#       5 df
#       6 columns=['Survived','Pclass','Age','Fare']
#       7 corr=df[columns].corr()
# ----> 8 sns.heatmap(data=corr,annot=True,cmap="coolwarm",vmin= -1,vmax= 1)
#       9 plt.title('correlation')
#      10 plt.show()
#
# File c:\Users\abC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# ...
